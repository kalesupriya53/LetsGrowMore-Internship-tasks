# %% [markdown]
# ## LetsGrowMore Virtual Internship Program (LGMVIP):  Data Science Intern MAY 2022
# ### Task3: Image to Pencil Sketch with python
# #### Author: Kale Supriya Ashok

# %%
import numpy as npS
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# imread(): This function will load image.
#
# cvtColor(): This function takes color as an argument and then changes the source image color into that color.
#
# bitwise_not(): This function will help the image to keep the properties as same by providing the masking to it.
#
# GaussianBlur(): This function is used to modify the image by sharpening the edgesof the image, smoothen the image and will minimize the blurring property.
#
# divide(): This function is used to normalization of the image as it doesn't loose its previos property.

# %%
image=cv2.imread(r"C:\Users\hp\Downloads\dog1.webp")
plt.figure(figsize=(8,8))

plt.imshow(image)
plt.axis("off")
plt.title("Original Image")
# cv2.imshow("Original Image",image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# Text(0.5, 1.0, 'Original Image')

# %% [markdown]
# ###### Now we will create new image by converting the original image to greyscale image.

# %%
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8))

plt.imshow(gray_image,cmap='gray')
plt.axis("off")
plt.title("GrayScale Image")

# cv2.imshow("Gray Scale Image",gray_image)
# cv2.waitKey(0)
# Out:
# Text(0.5, 1.0, 'GrayScale Image')

# %% [markdown]
# ##### Now we will invert new grayscale image.

# %%
inverted_image=cv2.bitwise_not(gray_image)
plt.figure(figsize=(8,8))
plt.imshow(inverted_image,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
# cv2.imshow("Inverted Image",inverted_image)
# cv2.waitKey(0)
# Out:
# Text(0.5, 1.0, 'Inverted Image')

# %% [markdown]
# #### Blur the image using Gaussian Function

# %%
smoothing_image=cv2.GaussianBlur(inverted_image,(21,21),sigmaX=0,sigmaY=0)
plt.figure(figsize=(8,8))

plt.imshow(smoothing_image,cmap='gray')
plt.axis("off")
plt.title("Smoothen Image")
# Out:
# Text(0.5, 1.0, 'Smoothen Image')

# %% [markdown]
# ##### Invert the blurred image
# ##### After inverting blurred image we can easily convert image to pencil scketch

# %%
# inverted_blurred= cv2.bitwise_not(blurred)
pencil_sketch=cv2.divide(gray_image,255-smoothing_image,scale=255)
plt.figure(figsize=(8,8))

plt.imshow(pencil_sketch,cmap='gray')
plt.axis("off")
plt.title("Pencil Sketch Image")
# cv2.imshow("Sketch",pencil_sketch)
# cv2.waitKey(0)
# Out:
# Text(0.5, 1.0, 'Pencil Sketch Image')

# %%
plt.figure(figsize=(20,20))
plt.subplot(1,5,1)
plt.imshow(image)
plt.axis("off")
plt.title("Original Image")

plt.subplot(1,5,2)
plt.imshow(gray_image,cmap='gray')
plt.axis("off")
plt.title("GrayScale Image")

plt.subplot(1,5,3)
plt.imshow(inverted_image,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")

plt.subplot(1,5,4)
plt.imshow(smoothing_image,cmap='gray')
plt.axis("off")
plt.title("Smoothen Image")

plt.subplot(1,5,5)
plt.imshow(pencil_sketch,cmap='gray')
plt.axis("off")
plt.title("Pencil Sketch Image")
# Out:
# Text(0.5, 1.0, 'Pencil Sketch Image')
